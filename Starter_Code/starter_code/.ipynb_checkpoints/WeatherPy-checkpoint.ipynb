# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import requests
import json
from datetime import datetime
# Import the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 601

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=" + weather_api_key

units = "metric"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url =  url + "&q=" + city
    print(city_url)
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        weather_response = requests.get(city_url)
        city_weather = weather_response.json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=stepnoye
# Processing Record 1 of Set 1 | stepnoye
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=margaret river
# Processing Record 2 of Set 1 | margaret river
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=mablethorpe
# Processing Record 3 of Set 1 | mablethorpe
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=mwinilunga
# Processing Record 4 of Set 1 | mwinilunga
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=adamstown
# Processing Record 5 of Set 1 | adamstown
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=edinburgh of the seven seas
# Processing Record 6 of Set 1 | edinburgh of the seven seas
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=tiksi
# Processing Record 7 of Set 1 | tiksi
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=nova sintra
# Processing Record 8 of Set 1 | nova sintra
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=buka
# Processing Record 9 of Set 1 | buka
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=sheregesh
# Processing Record 10 of Set 1 | sheregesh
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=saipan
# Processing Record 11 of Set 1 | saipan
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=miyako
# Processing Record 12 of Set 1 | miyako
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=hasaki
# Processing Record 13 of Set 1 | hasaki
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=aral
# Processing Record 14 of Set 1 | aral
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=bargaal
# Processing Record 15 of Set 1 | bargaal
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=jamestown
# Processing Record 16 of Set 1 | jamestown
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=hawaiian paradise park
# Processing Record 17 of Set 1 | hawaiian paradise park
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=longyearbyen
# Processing Record 18 of Set 1 | longyearbyen
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=taiohae
# Processing Record 19 of Set 1 | taiohae
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=sisimiut
# Processing Record 20 of Set 1 | sisimiut
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=codrington
# Processing Record 21 of Set 1 | codrington
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=port-aux-francais
# Processing Record 22 of Set 1 | port-aux-francais
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=tateyama
# Processing Record 23 of Set 1 | tateyama
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=avarua
# Processing Record 24 of Set 1 | avarua
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=albany
# Processing Record 25 of Set 1 | albany
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=camuy
# Processing Record 26 of Set 1 | camuy
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=iqaluit
# Processing Record 27 of Set 1 | iqaluit
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=domna
# Processing Record 28 of Set 1 | domna
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=puerto natales
# Processing Record 29 of Set 1 | puerto natales
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=dudinka
# Processing Record 30 of Set 1 | dudinka
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=great bend
# Processing Record 31 of Set 1 | great bend
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=waitangi
# Processing Record 32 of Set 1 | waitangi
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=whitehorse
# Processing Record 33 of Set 1 | whitehorse
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=choyr
# Processing Record 34 of Set 1 | choyr
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=port mathurin
# Processing Record 35 of Set 1 | port mathurin
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=invercargill
# Processing Record 36 of Set 1 | invercargill
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=hithadhoo
# Processing Record 37 of Set 1 | hithadhoo
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=east london
# Processing Record 38 of Set 1 | east london
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=brady
# Processing Record 39 of Set 1 | brady
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=guayaramerin
# Processing Record 40 of Set 1 | guayaramerin
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=yellowknife
# Processing Record 41 of Set 1 | yellowknife
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=olonkinbyen
# Processing Record 42 of Set 1 | olonkinbyen
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=vohipaho
# Processing Record 43 of Set 1 | vohipaho
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=aban
# Processing Record 44 of Set 1 | aban
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=afaahiti
# Processing Record 45 of Set 1 | afaahiti
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=port alfred
# Processing Record 46 of Set 1 | port alfred
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=zonguldak
# Processing Record 47 of Set 1 | zonguldak
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=ust'-kulom
# Processing Record 48 of Set 1 | ust'-kulom
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=robstown
# Processing Record 49 of Set 1 | robstown
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=mejit
# Processing Record 50 of Set 1 | mejit
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=djenne
# Processing Record 0 of Set 2 | djenne
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=tibanbang
# Processing Record 1 of Set 2 | tibanbang
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=papatowai
# Processing Record 2 of Set 2 | papatowai
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=tranovaho
# Processing Record 3 of Set 2 | tranovaho
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=stanley
# Processing Record 4 of Set 2 | stanley
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=paita
# Processing Record 5 of Set 2 | paita
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=hamilton
# Processing Record 6 of Set 2 | hamilton
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=khorugh
# Processing Record 7 of Set 2 | khorugh
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=thompson
# Processing Record 8 of Set 2 | thompson
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=tazovsky
# Processing Record 9 of Set 2 | tazovsky
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=chonchi
# Processing Record 10 of Set 2 | chonchi
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=kavaratti
# Processing Record 11 of Set 2 | kavaratti
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=colonia
# Processing Record 12 of Set 2 | colonia
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=pangody
# Processing Record 13 of Set 2 | pangody
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=trujillo
# Processing Record 14 of Set 2 | trujillo
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=tadine
# Processing Record 15 of Set 2 | tadine
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=haiku-pauwela
# Processing Record 16 of Set 2 | haiku-pauwela
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=berdyansk
# Processing Record 17 of Set 2 | berdyansk
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=recani
# Processing Record 18 of Set 2 | recani
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=port blair
# Processing Record 19 of Set 2 | port blair
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=saint-mandrier-sur-mer
# Processing Record 20 of Set 2 | saint-mandrier-sur-mer
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=banda aceh
# Processing Record 21 of Set 2 | banda aceh
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=ushirombo
# Processing Record 22 of Set 2 | ushirombo
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=vegreville
# Processing Record 23 of Set 2 | vegreville
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=kodiak
# Processing Record 24 of Set 2 | kodiak
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=cao bang
# Processing Record 25 of Set 2 | cao bang
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=west island
# Processing Record 26 of Set 2 | west island
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=ust-nera
# Processing Record 27 of Set 2 | ust-nera
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=gamba
# Processing Record 28 of Set 2 | gamba
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=chardara
# Processing Record 29 of Set 2 | chardara
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=zhanaozen
# Processing Record 30 of Set 2 | zhanaozen
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=namie
# Processing Record 31 of Set 2 | namie
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=grytviken
# Processing Record 32 of Set 2 | grytviken
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=petropavlovsk-kamchatsky
# Processing Record 33 of Set 2 | petropavlovsk-kamchatsky
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=cabo san lucas
# Processing Record 34 of Set 2 | cabo san lucas
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=oyama
# Processing Record 35 of Set 2 | oyama
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=shalkar
# Processing Record 36 of Set 2 | shalkar
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=college
# Processing Record 37 of Set 2 | college
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=saint-pierre
# Processing Record 38 of Set 2 | saint-pierre
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=nar'yan-mar
# Processing Record 39 of Set 2 | nar'yan-mar
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=ravar
# Processing Record 40 of Set 2 | ravar
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=newman
# Processing Record 41 of Set 2 | newman
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=greymouth
# Processing Record 42 of Set 2 | greymouth
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=atafu village
# Processing Record 43 of Set 2 | atafu village
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=orange cove
# Processing Record 44 of Set 2 | orange cove
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=ushuaia
# Processing Record 45 of Set 2 | ushuaia
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=ponta delgada
# Processing Record 46 of Set 2 | ponta delgada
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=udachny
# Processing Record 47 of Set 2 | udachny
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=talnakh
# Processing Record 48 of Set 2 | talnakh
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=blackmans bay
# Processing Record 49 of Set 2 | blackmans bay
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=st. john's
# Processing Record 0 of Set 3 | st. john's
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=umm kaddadah
# Processing Record 1 of Set 3 | umm kaddadah
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=kristiansund
# Processing Record 2 of Set 3 | kristiansund
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=westport
# Processing Record 3 of Set 3 | westport
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=bentiu
# Processing Record 4 of Set 3 | bentiu
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=chinde
# Processing Record 5 of Set 3 | chinde
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=tolanaro
# Processing Record 6 of Set 3 | tolanaro
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=arteche
# Processing Record 7 of Set 3 | arteche
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=iskateley
# Processing Record 8 of Set 3 | iskateley
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=xilin hot
# Processing Record 9 of Set 3 | xilin hot
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=puerto ayora
# Processing Record 10 of Set 3 | puerto ayora
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=lihue
# Processing Record 11 of Set 3 | lihue
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=polyarnyy
# Processing Record 12 of Set 3 | polyarnyy
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=rumoi
# Processing Record 13 of Set 3 | rumoi
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=porto novo
# Processing Record 14 of Set 3 | porto novo
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=tomatlan
# Processing Record 15 of Set 3 | tomatlan
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=eyl
# Processing Record 16 of Set 3 | eyl
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=bredasdorp
# Processing Record 17 of Set 3 | bredasdorp
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=i'zaz
# Processing Record 18 of Set 3 | i'zaz
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=ancud
# Processing Record 19 of Set 3 | ancud
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=lagos
# Processing Record 20 of Set 3 | lagos
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=anadyr
# Processing Record 21 of Set 3 | anadyr
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=ta`u
# Processing Record 22 of Set 3 | ta`u
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=palmer
# Processing Record 23 of Set 3 | palmer
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=puerto baquerizo moreno
# Processing Record 24 of Set 3 | puerto baquerizo moreno
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=kruisfontein
# Processing Record 25 of Set 3 | kruisfontein
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=pavlovsk
# Processing Record 26 of Set 3 | pavlovsk
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=nantucket
# Processing Record 27 of Set 3 | nantucket
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q='amran
# Processing Record 28 of Set 3 | 'amran
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=princeville
# Processing Record 29 of Set 3 | princeville
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=betio village
# Processing Record 30 of Set 3 | betio village
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=holualoa
# Processing Record 31 of Set 3 | holualoa
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=ferkessedougou
# Processing Record 32 of Set 3 | ferkessedougou
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=neiafu
# Processing Record 33 of Set 3 | neiafu
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=la ronge
# Processing Record 34 of Set 3 | la ronge
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=armacao de buzios
# Processing Record 35 of Set 3 | armacao de buzios
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=ribeira grande
# Processing Record 36 of Set 3 | ribeira grande
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=pendra
# Processing Record 37 of Set 3 | pendra
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=kudymkar
# Processing Record 38 of Set 3 | kudymkar
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=noumea
# Processing Record 39 of Set 3 | noumea
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=quellon
# Processing Record 40 of Set 3 | quellon
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=toga village
# Processing Record 41 of Set 3 | toga village
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=cam ranh
# Processing Record 42 of Set 3 | cam ranh
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=szamotuly
# Processing Record 43 of Set 3 | szamotuly
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=imbituba
# Processing Record 44 of Set 3 | imbituba
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=khovd
# Processing Record 45 of Set 3 | khovd
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=bilibino
# Processing Record 46 of Set 3 | bilibino
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=necochea
# Processing Record 47 of Set 3 | necochea
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=aplahoue
# Processing Record 48 of Set 3 | aplahoue
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=lahaina
# Processing Record 49 of Set 3 | lahaina
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=kailua-kona
# Processing Record 0 of Set 4 | kailua-kona
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=boca suno
# Processing Record 1 of Set 4 | boca suno
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=mount pearl
# Processing Record 2 of Set 4 | mount pearl
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=kakunodatemachi
# Processing Record 3 of Set 4 | kakunodatemachi
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=northam
# Processing Record 4 of Set 4 | northam
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=bethel
# Processing Record 5 of Set 4 | bethel
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=castillos
# Processing Record 6 of Set 4 | castillos
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=north battleford
# Processing Record 7 of Set 4 | north battleford
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=puerto san carlos
# Processing Record 8 of Set 4 | puerto san carlos
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=sungailiat
# Processing Record 9 of Set 4 | sungailiat
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=hanceville
# Processing Record 10 of Set 4 | hanceville
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=ilulissat
# Processing Record 11 of Set 4 | ilulissat
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=mokshan
# Processing Record 12 of Set 4 | mokshan
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=zemio
# Processing Record 13 of Set 4 | zemio
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=inhambane
# Processing Record 14 of Set 4 | inhambane
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=khandyga
# Processing Record 15 of Set 4 | khandyga
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=stephenville
# Processing Record 16 of Set 4 | stephenville
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=tabou
# Processing Record 17 of Set 4 | tabou
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=balqash
# Processing Record 18 of Set 4 | balqash
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=puerto escondido
# Processing Record 19 of Set 4 | puerto escondido
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=mount isa
# Processing Record 20 of Set 4 | mount isa
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=grand gaube
# Processing Record 21 of Set 4 | grand gaube
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=arkhangel'sk
# Processing Record 22 of Set 4 | arkhangel'sk
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=constantia
# Processing Record 23 of Set 4 | constantia
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=luena
# Processing Record 24 of Set 4 | luena
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=nabire
# Processing Record 25 of Set 4 | nabire
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=mongo
# Processing Record 26 of Set 4 | mongo
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=porbandar
# Processing Record 27 of Set 4 | porbandar
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=mtskheta
# Processing Record 28 of Set 4 | mtskheta
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=yemetsk
# Processing Record 29 of Set 4 | yemetsk
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=saint-lys
# Processing Record 30 of Set 4 | saint-lys
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=severnoye
# Processing Record 31 of Set 4 | severnoye
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=fada
# Processing Record 32 of Set 4 | fada
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=luderitz
# Processing Record 33 of Set 4 | luderitz
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=badger
# Processing Record 34 of Set 4 | badger
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=oak grove
# Processing Record 35 of Set 4 | oak grove
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=rongelap
# Processing Record 36 of Set 4 | rongelap
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=siavonga
# Processing Record 37 of Set 4 | siavonga
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=cardigan
# Processing Record 38 of Set 4 | cardigan
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=rio de janeiro
# Processing Record 39 of Set 4 | rio de janeiro
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=ban phe
# Processing Record 40 of Set 4 | ban phe
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=enewetak
# Processing Record 41 of Set 4 | enewetak
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=san mariano
# Processing Record 42 of Set 4 | san mariano
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=hermanus
# Processing Record 43 of Set 4 | hermanus
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=federal
# Processing Record 44 of Set 4 | federal
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=ivdel'
# Processing Record 45 of Set 4 | ivdel'
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=georgetown
# Processing Record 46 of Set 4 | georgetown
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=mandalgovi
# Processing Record 47 of Set 4 | mandalgovi
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=centerville
# Processing Record 48 of Set 4 | centerville
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=tura
# Processing Record 49 of Set 4 | tura
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=punta arenas
# Processing Record 0 of Set 5 | punta arenas
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=nyagan
# Processing Record 1 of Set 5 | nyagan
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=bel ombre
# Processing Record 2 of Set 5 | bel ombre
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=okha
# Processing Record 3 of Set 5 | okha
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=kiama
# Processing Record 4 of Set 5 | kiama
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=nea ionia
# Processing Record 5 of Set 5 | nea ionia
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=antonio enes
# Processing Record 6 of Set 5 | antonio enes
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=uturoa
# Processing Record 7 of Set 5 | uturoa
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=lodeynoye pole
# Processing Record 8 of Set 5 | lodeynoye pole
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=batam
# Processing Record 9 of Set 5 | batam
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=nouadhibou
# Processing Record 10 of Set 5 | nouadhibou
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=carnarvon
# Processing Record 11 of Set 5 | carnarvon
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=miguel aleman (la doce)
# Processing Record 12 of Set 5 | miguel aleman (la doce)
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=gadzhiyevo
# Processing Record 13 of Set 5 | gadzhiyevo
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=broken hill
# Processing Record 14 of Set 5 | broken hill
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=kanniyakumari
# Processing Record 15 of Set 5 | kanniyakumari
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=port elizabeth
# Processing Record 16 of Set 5 | port elizabeth
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=sur
# Processing Record 17 of Set 5 | sur
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=bandarbeyla
# Processing Record 18 of Set 5 | bandarbeyla
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=fort mcmurray
# Processing Record 19 of Set 5 | fort mcmurray
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=sitka
# Processing Record 20 of Set 5 | sitka
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=nemuro
# Processing Record 21 of Set 5 | nemuro
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=phek
# Processing Record 22 of Set 5 | phek
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=balboa
# Processing Record 23 of Set 5 | balboa
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=copalnic manastur
# Processing Record 24 of Set 5 | copalnic manastur
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=samitah
# Processing Record 25 of Set 5 | samitah
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=sabana grande de boya
# Processing Record 26 of Set 5 | sabana grande de boya
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=shahrud
# Processing Record 27 of Set 5 | shahrud
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=masterton
# Processing Record 28 of Set 5 | masterton
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=crane
# Processing Record 29 of Set 5 | crane
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=tayoltita
# Processing Record 30 of Set 5 | tayoltita
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=klyuchi
# Processing Record 31 of Set 5 | klyuchi
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=nova vicosa
# Processing Record 32 of Set 5 | nova vicosa
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=nouna
# Processing Record 33 of Set 5 | nouna
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=oranjemund
# Processing Record 34 of Set 5 | oranjemund
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=pyu
# Processing Record 35 of Set 5 | pyu
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=novo milosevo
# Processing Record 36 of Set 5 | novo milosevo
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=lake havasu city
# Processing Record 37 of Set 5 | lake havasu city
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=nuuk
# Processing Record 38 of Set 5 | nuuk
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=nicoya
# Processing Record 39 of Set 5 | nicoya
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=bansi
# Processing Record 40 of Set 5 | bansi
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=wuchang
# Processing Record 41 of Set 5 | wuchang
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=sonsorol village
# Processing Record 42 of Set 5 | sonsorol village
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=natchez
# Processing Record 43 of Set 5 | natchez
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=swakopmund
# Processing Record 44 of Set 5 | swakopmund
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=valparaiso
# Processing Record 45 of Set 5 | valparaiso
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=vodnyy
# Processing Record 46 of Set 5 | vodnyy
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=port-vila
# Processing Record 47 of Set 5 | port-vila
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=patan
# Processing Record 48 of Set 5 | patan
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=malanje
# Processing Record 49 of Set 5 | malanje
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=idrinskoye
# Processing Record 0 of Set 6 | idrinskoye
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=mushie
# Processing Record 1 of Set 6 | mushie
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=beboto
# Processing Record 2 of Set 6 | beboto
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=changnyeong
# Processing Record 3 of Set 6 | changnyeong
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=kapa'a
# Processing Record 4 of Set 6 | kapa'a
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=maceio
# Processing Record 5 of Set 6 | maceio
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=koryazhma
# Processing Record 6 of Set 6 | koryazhma
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=anamosa
# Processing Record 7 of Set 6 | anamosa
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=mianke mor
# Processing Record 8 of Set 6 | mianke mor
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=punta cana
# Processing Record 9 of Set 6 | punta cana
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=teknaf
# Processing Record 10 of Set 6 | teknaf
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=cehegin
# Processing Record 11 of Set 6 | cehegin
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=toliara
# Processing Record 12 of Set 6 | toliara
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=wailua homesteads
# Processing Record 13 of Set 6 | wailua homesteads
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=selfoss
# Processing Record 14 of Set 6 | selfoss
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=aldinga beach
# Processing Record 15 of Set 6 | aldinga beach
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=gakem
# Processing Record 16 of Set 6 | gakem
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=kamloops
# Processing Record 17 of Set 6 | kamloops
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=cleckheaton
# Processing Record 18 of Set 6 | cleckheaton
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=keflavik
# Processing Record 19 of Set 6 | keflavik
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=zhytomyr
# Processing Record 20 of Set 6 | zhytomyr
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=shenjiamen
# Processing Record 21 of Set 6 | shenjiamen
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=dordrecht
# Processing Record 22 of Set 6 | dordrecht
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=yarmouth
# Processing Record 23 of Set 6 | yarmouth
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=yuzhno-kurilsk
# Processing Record 24 of Set 6 | yuzhno-kurilsk
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=acarau
# Processing Record 25 of Set 6 | acarau
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=ironwood
# Processing Record 26 of Set 6 | ironwood
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=chu
# Processing Record 27 of Set 6 | chu
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=vychegodskiy
# Processing Record 28 of Set 6 | vychegodskiy
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=aitape
# Processing Record 29 of Set 6 | aitape
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=kudahuvadhoo
# Processing Record 30 of Set 6 | kudahuvadhoo
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=tiznit
# Processing Record 31 of Set 6 | tiznit
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=brookings
# Processing Record 32 of Set 6 | brookings
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=khanbari
# Processing Record 33 of Set 6 | khanbari
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=al-`ula
# Processing Record 34 of Set 6 | al-`ula
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=copiapo
# Processing Record 35 of Set 6 | copiapo
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=happy valley-goose bay
# Processing Record 36 of Set 6 | happy valley-goose bay
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=isafjordur
# Processing Record 37 of Set 6 | isafjordur
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=sault ste. marie
# Processing Record 38 of Set 6 | sault ste. marie
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=brodnica
# Processing Record 39 of Set 6 | brodnica
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=puerto santa
# Processing Record 40 of Set 6 | puerto santa
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=rechytsa
# Processing Record 41 of Set 6 | rechytsa
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=ciudad lazaro cardenas
# Processing Record 42 of Set 6 | ciudad lazaro cardenas
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=the pas
# Processing Record 43 of Set 6 | the pas
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=fuvahmulah
# Processing Record 44 of Set 6 | fuvahmulah
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=callao
# Processing Record 45 of Set 6 | callao
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=sinabang
# Processing Record 46 of Set 6 | sinabang
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=chernyshevskiy
# Processing Record 47 of Set 6 | chernyshevskiy
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=sakaraha
# Processing Record 48 of Set 6 | sakaraha
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=quatre cocos
# Processing Record 49 of Set 6 | quatre cocos
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=kimbe
# Processing Record 0 of Set 7 | kimbe
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=vila velha
# Processing Record 1 of Set 7 | vila velha
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=constitucion
# Processing Record 2 of Set 7 | constitucion
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=ta'izz
# Processing Record 3 of Set 7 | ta'izz
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=howrah
# Processing Record 4 of Set 7 | howrah
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=queenstown
# Processing Record 5 of Set 7 | queenstown
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=itacare
# Processing Record 6 of Set 7 | itacare
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=tsaratanana
# Processing Record 7 of Set 7 | tsaratanana
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=wenchang
# Processing Record 8 of Set 7 | wenchang
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=kapuskasing
# Processing Record 9 of Set 7 | kapuskasing
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=alofi
# Processing Record 10 of Set 7 | alofi
# ...
# Processing Record 47 of Set 10 | ciudad guayana
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=fonadhoo
# Processing Record 48 of Set 10 | fonadhoo
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=yung shue wan
# Processing Record 49 of Set 10 | yung shue wan
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=la gi
# Processing Record 0 of Set 11 | la gi
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=zhumysker
# Processing Record 1 of Set 11 | zhumysker
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=siwa oasis
# Processing Record 2 of Set 11 | siwa oasis
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=santa helena de goias
# Processing Record 3 of Set 11 | santa helena de goias
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=ishigaki
# Processing Record 4 of Set 11 | ishigaki
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=akureyri
# Processing Record 5 of Set 11 | akureyri
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=lawas
# Processing Record 6 of Set 11 | lawas
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=vorkuta
# Processing Record 7 of Set 11 | vorkuta
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=karratha
# Processing Record 8 of Set 11 | karratha
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=pontianak
# Processing Record 9 of Set 11 | pontianak
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=santyoku
# Processing Record 10 of Set 11 | santyoku
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=jumla
# Processing Record 11 of Set 11 | jumla
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=rayside-balfour
# Processing Record 12 of Set 11 | rayside-balfour
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=loreto
# Processing Record 13 of Set 11 | loreto
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=susuman
# Processing Record 14 of Set 11 | susuman
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=tamanrasset
# Processing Record 15 of Set 11 | tamanrasset
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=daman
# Processing Record 16 of Set 11 | daman
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=eraan
# Processing Record 17 of Set 11 | eraan
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=vila franca do campo
# Processing Record 18 of Set 11 | vila franca do campo
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=revda
# Processing Record 19 of Set 11 | revda
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=kaa-khem
# Processing Record 20 of Set 11 | kaa-khem
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=kletnya
# Processing Record 21 of Set 11 | kletnya
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=ulsteinvik
# Processing Record 22 of Set 11 | ulsteinvik
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=nizhniy odes
# Processing Record 23 of Set 11 | nizhniy odes
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=sivrice
# Processing Record 24 of Set 11 | sivrice
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=huainan
# Processing Record 25 of Set 11 | huainan
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=iskushuban
# Processing Record 26 of Set 11 | iskushuban
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=liberal
# Processing Record 27 of Set 11 | liberal
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=port saint john's
# Processing Record 28 of Set 11 | port saint john's
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=saint-francois
# Processing Record 29 of Set 11 | saint-francois
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=kindu
# Processing Record 30 of Set 11 | kindu
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=ugoofaaru
# Processing Record 31 of Set 11 | ugoofaaru
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=tralee
# Processing Record 32 of Set 11 | tralee
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=saynshand
# Processing Record 33 of Set 11 | saynshand
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=virginia
# Processing Record 34 of Set 11 | virginia
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=kaltungo
# Processing Record 35 of Set 11 | kaltungo
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=fort st. john
# Processing Record 36 of Set 11 | fort st. john
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=auki
# Processing Record 37 of Set 11 | auki
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=margate
# Processing Record 38 of Set 11 | margate
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=sarmiento
# Processing Record 39 of Set 11 | sarmiento
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=al khafji
# Processing Record 40 of Set 11 | al khafji
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=dauphin
# Processing Record 41 of Set 11 | dauphin
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=gunnedah
# Processing Record 42 of Set 11 | gunnedah
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=tokar
# Processing Record 43 of Set 11 | tokar
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=yatou
# Processing Record 44 of Set 11 | yatou
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=chany
# Processing Record 45 of Set 11 | chany
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=kharkhorin
# Processing Record 46 of Set 11 | kharkhorin
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=knik-fairview
# Processing Record 47 of Set 11 | knik-fairview
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=muzayri'
# Processing Record 48 of Set 11 | muzayri'
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=coahuayana de hidalgo
# Processing Record 49 of Set 11 | coahuayana de hidalgo
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=yalta
# Processing Record 0 of Set 12 | yalta
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=illela
# Processing Record 1 of Set 12 | illela
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=kone
# Processing Record 2 of Set 12 | kone
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=sadjoavato
# Processing Record 3 of Set 12 | sadjoavato
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=vanino
# Processing Record 4 of Set 12 | vanino
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=tual
# Processing Record 5 of Set 12 | tual
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=dunedin
# Processing Record 6 of Set 12 | dunedin
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=sekong
# Processing Record 7 of Set 12 | sekong
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=itaueira
# Processing Record 8 of Set 12 | itaueira
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=chibougamau
# Processing Record 9 of Set 12 | chibougamau
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=mugia
# Processing Record 10 of Set 12 | mugia
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=pathein
# Processing Record 11 of Set 12 | pathein
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=rutana
# Processing Record 12 of Set 12 | rutana
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=eqbaliyeh
# Processing Record 13 of Set 12 | eqbaliyeh
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=cadale
# Processing Record 14 of Set 12 | cadale
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=villeta
# Processing Record 15 of Set 12 | villeta
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=berbera
# Processing Record 16 of Set 12 | berbera
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=grand baie
# Processing Record 17 of Set 12 | grand baie
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=guarapari
# Processing Record 18 of Set 12 | guarapari
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=sarandi del yi
# Processing Record 19 of Set 12 | sarandi del yi
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=sengiley
# Processing Record 20 of Set 12 | sengiley
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=laguna
# Processing Record 21 of Set 12 | laguna
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=urangan
# Processing Record 22 of Set 12 | urangan
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=santa ana
# Processing Record 23 of Set 12 | santa ana
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=shimla
# Processing Record 24 of Set 12 | shimla
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=grasberg
# Processing Record 25 of Set 12 | grasberg
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=portland
# Processing Record 26 of Set 12 | portland
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=jasper
# Processing Record 27 of Set 12 | jasper
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=isla mujeres
# Processing Record 28 of Set 12 | isla mujeres
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=crucecita
# Processing Record 29 of Set 12 | crucecita
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=veinticinco de mayo
# Processing Record 30 of Set 12 | veinticinco de mayo
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=taoru
# Processing Record 31 of Set 12 | taoru
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=katiola
# Processing Record 32 of Set 12 | katiola
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=manokwari
# Processing Record 33 of Set 12 | manokwari
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=touros
# Processing Record 34 of Set 12 | touros
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=asosa
# Processing Record 35 of Set 12 | asosa
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=floro
# Processing Record 36 of Set 12 | floro
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=genhe
# Processing Record 37 of Set 12 | genhe
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=zaio
# Processing Record 38 of Set 12 | zaio
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=kismayo
# Processing Record 39 of Set 12 | kismayo
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=fergus falls
# Processing Record 40 of Set 12 | fergus falls
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=cananeia
# Processing Record 41 of Set 12 | cananeia
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=wynyard
# Processing Record 42 of Set 12 | wynyard
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=ulladulla
# Processing Record 43 of Set 12 | ulladulla
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=newport
# Processing Record 44 of Set 12 | newport
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=hilo
# Processing Record 45 of Set 12 | hilo
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=pekan
# Processing Record 46 of Set 12 | pekan
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=santiago del estero
# Processing Record 47 of Set 12 | santiago del estero
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=playa del ingles
# Processing Record 48 of Set 12 | playa del ingles
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=bikenibeu village
# Processing Record 49 of Set 12 | bikenibeu village
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=95ffb6407bc51d23269b92e5e400e768&q=weno
# Processing Record 0 of Set 13 | weno
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame.from_dict(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          573
# Lat           573
# Lng           573
# Max Temp      573
# Humidity      573
# Cloudiness    573
# Wind Speed    573
# Country       573
# Date          573
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#                           City      Lat       Lng  Max Temp  Humidity  \
# 0                     stepnoye  51.4000   46.8667     17.13        58
# 1               margaret river -33.9500  115.0667     16.78        70
# 2                   mwinilunga -11.7358   24.4293     13.63        72
# 3                    adamstown -25.0660 -130.1015     22.36        84
# 4  edinburgh of the seven seas -37.0676  -12.3116     12.02        76
#
#    Cloudiness  Wind Speed Country        Date
# 0         100        4.47      RU  1714269152
# 1          99        4.61      AU  1714269152
# 2          15        2.94      ZM  1714269152
# 3         100        4.95      PN  1714269152
# 4         100       14.61      SH  1714269152

# %%
# Export the City_Data into a csv
city_data_df.to_csv("../output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("../output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                                 City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 0                           stepnoye  51.4000   46.8667     17.13        58
# 1                     margaret river -33.9500  115.0667     16.78        70
# 2                         mwinilunga -11.7358   24.4293     13.63        72
# 3                          adamstown -25.0660 -130.1015     22.36        84
# 4        edinburgh of the seven seas -37.0676  -12.3116     12.02        76
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 0               100        4.47      RU  1714269152
# 1                99        4.61      AU  1714269152
# 2                15        2.94      ZM  1714269152
# 3               100        4.95      PN  1714269152
# 4               100       14.61      SH  1714269152

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df["Lat"], city_data_df["Max Temp"], alpha=.8, edgecolors="k")

#Formatting for date
date = datetime.now()
date = date.strftime("%m-%d-%Y")

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (C)")
plt.title(f"City Latitude vs. Temperature ({date})")
plt.grid(True) 
plt.tight_layout()

# Save the figure
plt.savefig("../output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df["Lat"], city_data_df["Humidity"], alpha=.8, edgecolors="k")

#Format date from UTC to m/d/y
date = datetime.now()
date = date.strftime("%m-%d-%Y")

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title(f"City Latitude vs. Humidity (%) ({date})")
plt.grid(True) 
plt.tight_layout()

# Save the figure
plt.savefig("../output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df["Lat"], city_data_df["Cloudiness"], alpha=.8, edgecolors="k")

#Format date from UTC to m/d/y
date = datetime.now()
date = date.strftime("%m-%d-%Y")

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.title(f"City Latitude vs. Cloudiness ({date})")
plt.grid(True) 
plt.tight_layout()

# Save the figure
plt.savefig("../output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df["Lat"], city_data_df["Wind Speed"], alpha=.8, edgecolors="k")

#Format date from UTC to m/d/y
date = datetime.now()
date = date.strftime("%m-%d-%Y")

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (m/s)")
plt.title(f"City Latitude vs. Wind Speed ({date})")
plt.grid(True) 
plt.tight_layout()

# Save the figure
plt.savefig("../output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
#(slope, intercept, rvalue, pvalue, stderr) = linregress(x_value, y_value)
#regress_values = x_value * slope + intercept
#line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[pd.to_numeric(city_data_df["Lat"]) > 0, :]


# Display sample data
northern_hemi_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0           stepnoye  51.4000   46.8667     17.13        58         100
# 5              tiksi  71.6872  128.8694    -12.99        74          88
# 6        nova sintra  14.8667  -24.7167     23.77        82         100
# 7               buka  40.8108   69.1986      7.59        55          60
# 8          sheregesh  52.9209   87.9869      5.53        88          42
#
#          Wind Speed Country        Date
# City_ID
# 0              4.47      RU  1714269152
# 5              1.00      RU  1714269152
# 6              7.30      CV  1714269152
# 7              3.10      UZ  1714269152
# 8              1.50      RU  1714269152

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[pd.to_numeric(city_data_df["Lat"]) < 0, :]

# Display sample data
southern_hemi_df.head()
# Out:
#                                 City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 1                     margaret river -33.9500  115.0667     16.78        70
# 2                         mwinilunga -11.7358   24.4293     13.63        72
# 3                          adamstown -25.0660 -130.1015     22.36        84
# 4        edinburgh of the seven seas -37.0676  -12.3116     12.02        76
# 18                        codrington -38.2667  141.9667     18.62        40
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 1                99        4.61      AU  1714269152
# 2                15        2.94      ZM  1714269152
# 3               100        4.95      PN  1714269152
# 4               100       14.61      SH  1714269152
# 18                0        6.54      AU  1714269153

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_value = northern_hemi_df["Lat"]
y_value = northern_hemi_df["Max Temp"]
slope = linregress(x_value, y_value)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_value, y_value)
regress_value = x_value * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#Plot values
plt.scatter(x_value, y_value)
plt.plot(x_value, regress_value, "-r")
plt.annotate(line_eq,(0,-20),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Max Temp")
print(f'The r-value is {rvalue}')
print("-----------------------------------")
print("Observations about linear relationship:")
print("The regression displays a negative relationship between temperature and latitude")
print("In the northern hemisphere, as the latitude increases the distance from the equator increases")
print("As you move away from the equator, the max temperature decreases.")
# Out:
# The r-value is -0.882296944930194
# -----------------------------------
# Observations about linear relationship:
# The regression displays a negative relationship between temperature and latitude
# In the northern hemisphere, as the latitude increases the distance from the equator increases
# As you move away from the equator, the max temperature decreases.

# %%
# Linear regression on Southern Hemisphere
x_value = southern_hemi_df["Lat"]
y_value = southern_hemi_df["Max Temp"]
slope = linregress(x_value, y_value)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_value, y_value)
regress_value = x_value * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#Plot values
plt.scatter(x_value, y_value)
plt.plot(x_value, regress_value, "-r")
plt.annotate(line_eq,(-25,15),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Max Temp")
print(f'The r-value is {rvalue}')
print("-----------------------------------")
print("Observations about linear relationship:")
print("The regression displays a sligtly positive relationship between temperature and latitude.")
print("In the southern hemisphere, as the latitude increases the distance from the equator decreases")
print("As you move closer to the equator, the max temperature generally increases.")
# Out:
# The r-value is 0.7286575592248122
# -----------------------------------
# Observations about linear relationship:
# The regression displays a sligtly positive relationship between temperature and latitude.
# In the southern hemisphere, as the latitude increases the distance from the equator decreases
# As you move closer to the equator, the max temperature generally increases.

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_value = northern_hemi_df["Lat"]
y_value = northern_hemi_df["Humidity"]
slope = linregress(x_value, y_value)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_value, y_value)
regress_value = x_value * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#Plot values
plt.scatter(x_value, y_value)
plt.plot(x_value, regress_value, "-r")
plt.annotate(line_eq,(40,20),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
print(f'The r-value is {rvalue}')
print("-----------------------------------")
print("Observations about linear relationship:")
print("The relationship is slightly positive, though there doesn't appear to be a strong coorelation between humidity and latitude.")
# Out:
# The r-value is 0.138494956551959
# -----------------------------------
# Observations about linear relationship:
# The relationship is slightly positive, though there doesn't appear to be a strong coorelation between humidity and latitude.

# %%
# Southern Hemisphere
x_value = southern_hemi_df["Lat"]
y_value = southern_hemi_df["Humidity"]
slope = linregress(x_value, y_value)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_value, y_value)
regress_value = x_value * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#Plot values
plt.scatter(x_value, y_value)
plt.plot(x_value, regress_value, "-r")
plt.annotate(line_eq,(-25,25),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
print(f'The r-value is {rvalue}')
print("-----------------------------------")
print("Observations about linear relationship:")
print("The relationship is slightly positive.")
print("Humidity increases as cities get closer to the equator.")
# Out:
# The r-value is 0.3299632951673024
# -----------------------------------
# Observations about linear relationship:
# The relationship is slightly positive.
# Humidity increases as cities get closer to the equator.

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_value = northern_hemi_df["Lat"]
y_value = northern_hemi_df["Cloudiness"]
slope = linregress(x_value, y_value)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_value, y_value)
regress_value = x_value * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#Plot values
plt.scatter(x_value, y_value)
plt.plot(x_value, regress_value, "-r")
plt.annotate(line_eq,(40,20),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
print(f'The r-value is {rvalue}')
print("-----------------------------------")
print("Observations about linear relationship:")
print("There does not appear to be a coorelation between latitude and cloudiness.")
# Out:
# The r-value is 0.1232451560127071
# -----------------------------------
# Observations about linear relationship:
# There does not appear to be a coorelation between latitude and cloudiness.

# %%
# Southern Hemisphere
x_value = southern_hemi_df["Lat"]
y_value = southern_hemi_df["Cloudiness"]
slope = linregress(x_value, y_value)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_value, y_value)
regress_value = x_value * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#Plot values
plt.scatter(x_value, y_value)
plt.plot(x_value, regress_value, "-r")
plt.annotate(line_eq,(-25,15),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
print(f'The r-value is {rvalue}')
print("-----------------------------------")
print("Observations about linear relationship:")
print("There does not appear to be a coorelation between latitude and cloudiness.")
# Out:
# The r-value is 0.17294341979062866
# -----------------------------------
# Observations about linear relationship:
# There does not appear to be a coorelation between latitude and cloudiness.

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_value = northern_hemi_df["Lat"]
y_value = northern_hemi_df["Wind Speed"]
slope = linregress(x_value, y_value)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_value, y_value)
regress_value = x_value * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#Plot values
plt.scatter(x_value, y_value)
plt.plot(x_value, regress_value, "-r")
plt.annotate(line_eq,(15,10),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
print(f'The r-value is {rvalue}')
print("-----------------------------------")
print("Observations about linear relationship:")
print("There does not appear to be a coorelation between latitude and wind speed.")
# Out:
# The r-value is 0.03727553727801878
# -----------------------------------
# Observations about linear relationship:
# There does not appear to be a coorelation between latitude and wind speed.

# %%
# Southern Hemisphere
x_value = southern_hemi_df["Lat"]
y_value = southern_hemi_df["Wind Speed"]
slope = linregress(x_value, y_value)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_value, y_value)
regress_value = x_value * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#Plot values
plt.scatter(x_value, y_value)
plt.plot(x_value, regress_value, "-r")
plt.annotate(line_eq,(-25,10),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
print(f'The r-value is {rvalue}')
print("-----------------------------------")
print("Observations about linear relationship:")
print("There does not appear to be a coorelation between latitude and wind speed.")
# Out:
# The r-value is -0.2158863519698308
# -----------------------------------
# Observations about linear relationship:
# There does not appear to be a coorelation between latitude and wind speed.

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
